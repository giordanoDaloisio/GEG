# %%
import pandas as pd

# %%
cmc = pd.read_csv('data/cmc.csv')

# %%
cmc['contr_use'].value_counts(normalize=True)
# Out:
# contr_use
# 1    0.427020
# 3    0.346911
# 2    0.226069
# Name: proportion, dtype: float64

# %%
crime = pd.read_csv('data/crime.csv')

# %%
crime['ViolentCrimesClass'].value_counts(normalize=True)
# Out:
# ViolentCrimesClass
# 100.0    0.237713
# 300.0    0.211635
# 400.0    0.199097
# 500.0    0.193581
# 200.0    0.157974
# Name: proportion, dtype: float64

# %%
drug = pd.read_csv('data/drug.csv')
drug['y'].value_counts(normalize=True)
# Out:
# y
# 2    0.529973
# 1    0.250928
# 0    0.219098
# Name: proportion, dtype: float64

# %%
law = pd.read_csv('data/law.csv')
law['gpa'].value_counts(normalize=True)
# Out:
# gpa
# 0    0.415773
# 2    0.311353
# 1    0.272874
# Name: proportion, dtype: float64

# %%
obesity = pd.read_csv('data/obesity.csv')
obesity['y'].value_counts(normalize=True)
# Out:
# y
# 3    0.235570
# 1    0.194631
# 2    0.194631
# 0    0.192617
# 4    0.182550
# Name: proportion, dtype: float64

# %%
park = pd.read_csv('data/park.csv')
park['score_cut'].value_counts(normalize=True)
# Out:
# score_cut
# 1    0.446298
# 0    0.304170
# 2    0.249532
# Name: proportion, dtype: float64

# %%
wine = pd.read_csv('data/wine.csv')
wine['quality'].value_counts(normalize=True)
# Out:
# quality
# 6    0.452610
# 5    0.341178
# 7    0.172110
# 4    0.034102
# Name: proportion, dtype: float64

# %%
adult = pd.read_csv('data/adult.csv')
adult['income'].value_counts(normalize=True)
# Out:
# income
# 0    0.757466
# 1    0.242534
# Name: proportion, dtype: float64

# %%
compas = pd.read_csv('data/compas.csv')
compas['two_year_recid'].value_counts(normalize=True)
# Out:
# two_year_recid
# 0.0    0.544511
# 1.0    0.455489
# Name: proportion, dtype: float64

# %%
german = pd.read_csv('data/german.csv')
german['credit'].value_counts(normalize=True)
# Out:
# credit
# 1.0    0.7
# 0.0    0.3
# Name: proportion, dtype: float64
